# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/netflix_movies (1).csv')

# %%
ds.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
ds.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
ds.shape
# Out:
# (8807, 12)

# %%
mode_value1=ds["director"].mode()
print(mode_value1)
# Out:
# 0    Rajiv Chilaka
# Name: director, dtype: object

# %%
mode_value2=ds["cast"].mode()
print(mode_value2)
# Out:
# 0    David Attenborough
# Name: cast, dtype: object

# %%
mode_value3=ds["country"].mode()
print(mode_value3)
# Out:
# 0    United States
# Name: country, dtype: object

# %%
mode_value4=ds["date_added"].mode()
print(mode_value4)
# Out:
# 0    January 1, 2020
# Name: date_added, dtype: object

# %%
mode_value5=ds["rating"].mode()
print(mode_value5)
# Out:
# 0    TV-MA
# Name: rating, dtype: object

# %%
mode_value6=ds["duration"].mode()
print(mode_value6)
# Out:
# 0    1 Season
# Name: duration, dtype: object

# %%
ds['director'].fillna(ds['director'].mode()[0], inplace=True)
ds['cast'].fillna(ds['cast'].mode()[0], inplace=True)
ds['country'].fillna(ds['country'].mode()[0], inplace=True)
ds['date_added'].fillna(ds['date_added'].mode()[0], inplace=True)
ds['rating'].fillna(ds['rating'].mode()[0], inplace=True)
ds['duration'].fillna(ds['duration'].mode()[0], inplace=True)

# %%
ds.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
ds.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                  Rajiv Chilaka
# 2                Julien Leclercq
# 3                  Rajiv Chilaka
# 4                  Rajiv Chilaka
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# #questions

# %%
# Find out which types of genre has most movies and TV Shows

most_common_genre = ds['listed_in'].str.split(', ').explode().mode()[0]

print(f"The most common genre is: {most_common_genre}")
# Out:
# The most common genre is: International Movies

# %%
#for visual representation using plots

plt.figure(figsize=(12, 6))
sns.histplot(x=genre_counts.index)
plt.xticks(rotation=90)
plt.title('Distribution of Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
# Get the top 10 countries contributing the most content
top_countries = ds['country'].value_counts().nlargest(10)

print(top_countries)
# Out:
# country
# United States     3649
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=ds, x='country') # Use 'country' as a string to refer to the column in ds
plt.xticks(rotation=90)
plt.title('top 10 countries contributing the most content')
plt.xlabel('Country') # Change xlabel to 'Country' for better clarity
plt.ylabel('Count')
plt.show()
